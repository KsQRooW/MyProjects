# %%
a = '30 Ноября'
list1 = a.lower().split()
replacer = {'нояб': 'Nov', 'янв': 'Jan'}
list1
# Out:
# ['30', 'ноября']

# %%
list(map(lambda x: list1[1].startswith(x), replacer.keys()))
# Out:
# [True, False]

# %%
replacer.keys()
# Out:
# dict_keys(['нояб', 'янв'])

# %%
a = '08.01.1999'
list1 = list(map(int, a.split('.')))
list1
# Out:
# [8, 1, 1999]
